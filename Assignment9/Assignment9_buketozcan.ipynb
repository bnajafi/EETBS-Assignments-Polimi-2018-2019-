# %% [markdown]
# ## Assignment 9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# importing the external files

# %%
ExternalFilesFolder =  r"/Users/apple/Desktop/python4ScientificComputing_Numpy_Pandas_MATPLotLIB/ExternalFiles"
ConsumptionFileName= "consumption_5545.csv"
TemperatureFileName= "Austin_weather_2014.csv"
IrradianceFileName= "irradiance_2014_gen.csv"

# %%
path_consumptionFile = os.path.join(ExternalFilesFolder,ConsumptionFileName)
path_TemperatureFile = os.path.join(ExternalFilesFolder,TemperatureFileName)
path_IrradianceFile = os.path.join(ExternalFilesFolder,IrradianceFileName)

# %% [markdown]
# reading the files and changing the indexes for consumption data:

# %%
DF_consumption = pd.read_csv(path_consumptionFile,sep=",", index_col=0)
DF_consumption.head()
DF_consumption.tail(10)
# Out:
#                      air conditioner_5545
# 2014-12-30 20:00:00                   0.0
# 2014-12-30 21:00:00                   0.0
# 2014-12-30 22:00:00                   0.0
# 2014-12-30 23:00:00                   0.0
# 2014-12-31 00:00:00                   0.0
# 2014-12-31 01:00:00                   NaN
# 2014-12-31 02:00:00                   NaN
# 2014-12-31 03:00:00                   NaN
# 2014-12-31 04:00:00                   NaN
# 2014-12-31 05:00:00                   NaN

# %%
PreviousIndex = DF_consumption.index
NewParsedIndex= pd.to_datetime(PreviousIndex)
DF_consumption.index =NewParsedIndex

# %%
DF_consumption_someDaysInJuly=DF_consumption["2014-07-01 00:00:00":"2014-07-03 23:00:00"]

# %%
plt.figure()
plt.plot(DF_consumption_someDaysInJuly)
plt.xlabel("Time")
plt.ylabel("AC Power (W)")
plt.show()

# %% [markdown]
# reading the files and changing the indexes for weather data:

# %%
DF_weather = pd.read_csv(path_TemperatureFile,sep=";",index_col=0)
DF_weather.head(24)
previousIndex_weather=DF_weather.index
newIndex_weather=pd.to_datetime(previousIndex_weather)
DF_weather.index = newIndex_weather
DF_weather.columns
Series_Temperature = DF_weather["temperature"]

# %%
DF_Temperature= DF_weather[["temperature"]]
DF_Temperature.head()
# Out:
#                      temperature
# localhour
# 2014-01-01 06:00:00        40.36
# 2014-01-01 07:00:00        38.11
# 2014-01-01 08:00:00        38.65
# 2014-01-01 09:00:00        38.47
# 2014-01-01 10:00:00        38.00

# %% [markdown]
# reading the files for irradiance data:

# %%
DF_irradianceSource = pd.read_csv(path_IrradianceFile,sep=";",index_col=1)
DF_irradianceSource.head(24)
# Out:
#                      dataid       use      air1  air2  air3  airwindowunit1  \
# localhour
# 2014-01-01 00:00:00    8236  0.303150  0.000000   NaN   NaN             NaN
# 2014-01-01 01:00:00    8236  0.358567  0.000000   NaN   NaN             NaN
# 2014-01-01 02:00:00    8236  0.367283  0.000000   NaN   NaN             NaN
# 2014-01-01 03:00:00    8236  0.350333  0.000000   NaN   NaN             NaN
# 2014-01-01 04:00:00    8236  0.562517  0.000000   NaN   NaN             NaN
# 2014-01-01 05:00:00    8236  0.570533  0.000000   NaN   NaN             NaN
# 2014-01-01 06:00:00    8236  0.434200  0.000000   NaN   NaN             NaN
# 2014-01-01 07:00:00    8236  0.459183  0.000000   NaN   NaN             NaN
# 2014-01-01 08:00:00    8236  0.589850  0.000500   NaN   NaN             NaN
# 2014-01-01 09:00:00    8236  0.776917  0.000050   NaN   NaN             NaN
# 2014-01-01 10:00:00    8236  0.773833  0.001033   NaN   NaN             NaN
# 2014-01-01 11:00:00    8236  0.644350  0.001667   NaN   NaN             NaN
# 2014-01-01 12:00:00    8236  0.722133  0.002650   NaN   NaN             NaN
# 2014-01-01 13:00:00    8236  0.185183  0.000100   NaN   NaN             NaN
# 2014-01-01 14:00:00    8236  0.176967  0.000000   NaN   NaN             NaN
# 2014-01-01 15:00:00    8236  0.306867  0.000000   NaN   NaN             NaN
# 2014-01-01 16:00:00    8236  0.430567  0.000350   NaN   NaN             NaN
# 2014-01-01 17:00:00    8236  0.731383  0.000000   NaN   NaN             NaN
# 2014-01-01 18:00:00    8236  0.932633  0.003233   NaN   NaN             NaN
# 2014-01-01 19:00:00    8236  1.019967  0.000633   NaN   NaN             NaN
# 2014-01-01 20:00:00    8236  0.749900  0.000300   NaN   NaN             NaN
# 2014-01-01 21:00:00    8236  0.551567  0.000000   NaN   NaN             NaN
# 2014-01-01 22:00:00    8236  0.479500  0.000000   NaN   NaN             NaN
# 2014-01-01 23:00:00    8236  0.233467  0.000000   NaN   NaN             NaN
#
#                      aquarium1  bathroom1  bathroom2  bedroom1     ...       \
# localhour                                                          ...
# 2014-01-01 00:00:00        NaN        NaN        NaN  0.005100     ...
# 2014-01-01 01:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 02:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 03:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 04:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 05:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 06:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 07:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 08:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 09:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 10:00:00        NaN        NaN        NaN  0.004683     ...
# 2014-01-01 11:00:00        NaN        NaN        NaN  0.000767     ...
# 2014-01-01 12:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 13:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 14:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 15:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 16:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 17:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 18:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 19:00:00        NaN        NaN        NaN  0.000000     ...
# 2014-01-01 20:00:00        NaN        NaN        NaN  0.008933     ...
# 2014-01-01 21:00:00        NaN        NaN        NaN  0.021983     ...
# 2014-01-01 22:00:00        NaN        NaN        NaN  0.017400     ...
# 2014-01-01 23:00:00        NaN        NaN        NaN  0.009633     ...
#
#                      refrigerator1  refrigerator2  security1  shed1  \
# localhour
# 2014-01-01 00:00:00       0.051567            NaN        NaN    NaN
# 2014-01-01 01:00:00       0.013417            NaN        NaN    NaN
# 2014-01-01 02:00:00       0.016283            NaN        NaN    NaN
# 2014-01-01 03:00:00       0.025300            NaN        NaN    NaN
# 2014-01-01 04:00:00       0.029950            NaN        NaN    NaN
# 2014-01-01 05:00:00       0.046233            NaN        NaN    NaN
# 2014-01-01 06:00:00       0.027300            NaN        NaN    NaN
# 2014-01-01 07:00:00       0.053967            NaN        NaN    NaN
# 2014-01-01 08:00:00       0.027433            NaN        NaN    NaN
# 2014-01-01 09:00:00       0.109050            NaN        NaN    NaN
# 2014-01-01 10:00:00       0.198967            NaN        NaN    NaN
# 2014-01-01 11:00:00       0.029417            NaN        NaN    NaN
# 2014-01-01 12:00:00       0.058333            NaN        NaN    NaN
# 2014-01-01 13:00:00       0.025333            NaN        NaN    NaN
# 2014-01-01 14:00:00       0.026883            NaN        NaN    NaN
# 2014-01-01 15:00:00       0.068900            NaN        NaN    NaN
# 2014-01-01 16:00:00       0.037017            NaN        NaN    NaN
# 2014-01-01 17:00:00       0.058050            NaN        NaN    NaN
# 2014-01-01 18:00:00       0.041050            NaN        NaN    NaN
# 2014-01-01 19:00:00       0.119417            NaN        NaN    NaN
# 2014-01-01 20:00:00       0.090150            NaN        NaN    NaN
# 2014-01-01 21:00:00       0.029767            NaN        NaN    NaN
# 2014-01-01 22:00:00       0.054950            NaN        NaN    NaN
# 2014-01-01 23:00:00       0.026017            NaN        NaN    NaN
#
#                      sprinkler1  utilityroom1  venthood1  waterheater1  \
# localhour
# 2014-01-01 00:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 01:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 02:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 03:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 04:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 05:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 06:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 07:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 08:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 09:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 10:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 11:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 12:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 13:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 14:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 15:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 16:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 17:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 18:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 19:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 20:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 21:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 22:00:00         NaN           NaN        NaN           NaN
# 2014-01-01 23:00:00         NaN           NaN        NaN           NaN
#
#                      waterheater2  winecooler1
# localhour
# 2014-01-01 00:00:00           NaN          NaN
# 2014-01-01 01:00:00           NaN          NaN
# 2014-01-01 02:00:00           NaN          NaN
# 2014-01-01 03:00:00           NaN          NaN
# 2014-01-01 04:00:00           NaN          NaN
# 2014-01-01 05:00:00           NaN          NaN
# 2014-01-01 06:00:00           NaN          NaN
# 2014-01-01 07:00:00           NaN          NaN
# 2014-01-01 08:00:00           NaN          NaN
# 2014-01-01 09:00:00           NaN          NaN
# 2014-01-01 10:00:00           NaN          NaN
# 2014-01-01 11:00:00           NaN          NaN
# 2014-01-01 12:00:00           NaN          NaN
# 2014-01-01 13:00:00           NaN          NaN
# 2014-01-01 14:00:00           NaN          NaN
# 2014-01-01 15:00:00           NaN          NaN
# 2014-01-01 16:00:00           NaN          NaN
# 2014-01-01 17:00:00           NaN          NaN
# 2014-01-01 18:00:00           NaN          NaN
# 2014-01-01 19:00:00           NaN          NaN
# 2014-01-01 20:00:00           NaN          NaN
# 2014-01-01 21:00:00           NaN          NaN
# 2014-01-01 22:00:00           NaN          NaN
# 2014-01-01 23:00:00           NaN          NaN
#
# [24 rows x 68 columns]

# %%
DF_irradiance=DF_irradianceSource[["gen"]]
DF_irradiance.head(24)
# Out:
#                           gen
# localhour
# 2014-01-01 00:00:00 -0.005967
# 2014-01-01 01:00:00 -0.006317
# 2014-01-01 02:00:00 -0.006350
# 2014-01-01 03:00:00 -0.006267
# 2014-01-01 04:00:00 -0.006767
# 2014-01-01 05:00:00 -0.006750
# 2014-01-01 06:00:00 -0.006500
# 2014-01-01 07:00:00  0.052800
# 2014-01-01 08:00:00  0.773583
# 2014-01-01 09:00:00  2.097700
# 2014-01-01 10:00:00  3.036750
# 2014-01-01 11:00:00  2.384400
# 2014-01-01 12:00:00  1.795133
# 2014-01-01 13:00:00  2.558650
# 2014-01-01 14:00:00  2.628450
# 2014-01-01 15:00:00  0.930317
# 2014-01-01 16:00:00  0.496167
# 2014-01-01 17:00:00  0.173800
# 2014-01-01 18:00:00 -0.007067
# 2014-01-01 19:00:00 -0.005217
# 2014-01-01 20:00:00 -0.004950
# 2014-01-01 21:00:00 -0.005067
# 2014-01-01 22:00:00 -0.005333
# 2014-01-01 23:00:00 -0.005933

# %%
DF_irradiance["gen"]<0
DF_irradiance[DF_irradiance["gen"]<0] = 0
DF_irradiance.head(24)
# Out:
# /Users/apple/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/apple/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/pandas/core/frame.py:2346: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc._setitem_with_indexer(indexer, value)
# /Users/apple/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/pandas/core/frame.py:2326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_array(key, value)
#                           gen
# localhour
# 2014-01-01 00:00:00  0.000000
# 2014-01-01 01:00:00  0.000000
# 2014-01-01 02:00:00  0.000000
# 2014-01-01 03:00:00  0.000000
# 2014-01-01 04:00:00  0.000000
# 2014-01-01 05:00:00  0.000000
# 2014-01-01 06:00:00  0.000000
# 2014-01-01 07:00:00  0.052800
# 2014-01-01 08:00:00  0.773583
# 2014-01-01 09:00:00  2.097700
# 2014-01-01 10:00:00  3.036750
# 2014-01-01 11:00:00  2.384400
# 2014-01-01 12:00:00  1.795133
# 2014-01-01 13:00:00  2.558650
# 2014-01-01 14:00:00  2.628450
# 2014-01-01 15:00:00  0.930317
# 2014-01-01 16:00:00  0.496167
# 2014-01-01 17:00:00  0.173800
# 2014-01-01 18:00:00  0.000000
# 2014-01-01 19:00:00  0.000000
# 2014-01-01 20:00:00  0.000000
# 2014-01-01 21:00:00  0.000000
# 2014-01-01 22:00:00  0.000000
# 2014-01-01 23:00:00  0.000000

# %% [markdown]
# We joined in a plot the consumption, temperature and generation.

# %%
DF_joined = DF_consumption.join([DF_Temperature,DF_irradiance])
DF_joined.head(24)
# Out:
#                      air conditioner_5545  temperature       gen
# 2014-01-01 00:00:00                   NaN          NaN  0.000000
# 2014-01-01 01:00:00                   NaN          NaN  0.000000
# 2014-01-01 02:00:00                   NaN          NaN  0.000000
# 2014-01-01 03:00:00                   NaN          NaN  0.000000
# 2014-01-01 04:00:00                   NaN          NaN  0.000000
# 2014-01-01 05:00:00                   NaN          NaN  0.000000
# 2014-01-01 06:00:00                   0.0        40.36  0.000000
# 2014-01-01 07:00:00                   0.0        38.11  0.052800
# 2014-01-01 08:00:00                   0.0        38.65  0.773583
# 2014-01-01 09:00:00                   0.0        38.47  2.097700
# 2014-01-01 10:00:00                   0.0        38.00  3.036750
# 2014-01-01 11:00:00                   0.0        38.85  2.384400
# 2014-01-01 12:00:00                   0.0        39.36  1.795133
# 2014-01-01 13:00:00                   0.0        37.86  2.558650
# 2014-01-01 14:00:00                   0.0        38.97  2.628450
# 2014-01-01 15:00:00                   0.0        45.85  0.930317
# 2014-01-01 16:00:00                   0.0        51.42  0.496167
# 2014-01-01 17:00:00                   0.0        57.66  0.173800
# 2014-01-01 18:00:00                   0.0        60.49  0.000000
# 2014-01-01 19:00:00                   0.0        63.36  0.000000
# 2014-01-01 20:00:00                   0.0        65.15  0.000000
# 2014-01-01 21:00:00                   0.0        64.19  0.000000
# 2014-01-01 22:00:00                   0.0        64.68  0.000000
# 2014-01-01 23:00:00                   0.0        62.25  0.000000

# %%
DF_joined_cleaned = DF_joined.dropna()
DF_joined_cleaned.head(24)
# Out:
#                      air conditioner_5545  temperature       gen
# 2014-01-01 06:00:00                   0.0        40.36  0.000000
# 2014-01-01 07:00:00                   0.0        38.11  0.052800
# 2014-01-01 08:00:00                   0.0        38.65  0.773583
# 2014-01-01 09:00:00                   0.0        38.47  2.097700
# 2014-01-01 10:00:00                   0.0        38.00  3.036750
# 2014-01-01 11:00:00                   0.0        38.85  2.384400
# 2014-01-01 12:00:00                   0.0        39.36  1.795133
# 2014-01-01 13:00:00                   0.0        37.86  2.558650
# 2014-01-01 14:00:00                   0.0        38.97  2.628450
# 2014-01-01 15:00:00                   0.0        45.85  0.930317
# 2014-01-01 16:00:00                   0.0        51.42  0.496167
# 2014-01-01 17:00:00                   0.0        57.66  0.173800
# 2014-01-01 18:00:00                   0.0        60.49  0.000000
# 2014-01-01 19:00:00                   0.0        63.36  0.000000
# 2014-01-01 20:00:00                   0.0        65.15  0.000000
# 2014-01-01 21:00:00                   0.0        64.19  0.000000
# 2014-01-01 22:00:00                   0.0        64.68  0.000000
# 2014-01-01 23:00:00                   0.0        62.25  0.000000
# 2014-01-02 00:00:00                   0.0        58.12  0.000000
# 2014-01-02 01:00:00                   0.0        55.78  0.000000
# 2014-01-02 02:00:00                   0.0        55.53  0.000000
# 2014-01-02 03:00:00                   0.0        53.57  0.000000
# 2014-01-02 04:00:00                   0.0        53.57  0.000000
# 2014-01-02 05:00:00                   0.0        49.05  0.000000

# %%
DF_joined_cleaned_copy = DF_joined.dropna().copy()

# %% [markdown]
# We summarize the tendency of the values on that selected dates.

# %%
DF_joined_cleaned_chosenDates = DF_joined_cleaned_copy["2014-08-01":"2014-08-04"]

# %%
DF_joined_cleaned_chosenDates["temperature"]=DF_joined_cleaned_chosenDates["temperature"].shift(-5)
DF_joined_cleaned_chosenDates.dropna()
DF_joined_cleaned_chosenDates.head()
DF_joined_cleaned_chosenDates.describe()
# Out:
# /Users/apple/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#        air conditioner_5545  temperature        gen
# count             96.000000    91.000000  96.000000
# mean             781.358854    80.013407   1.192847
# std              837.731453     6.989329   1.466490
# min                0.000000    67.390000   0.000000
# 25%                0.000000    74.290000   0.000000
# 50%              484.775000    79.000000   0.278442
# 75%             1381.416667    86.770000   2.533913
# max             2515.400000    92.440000   4.300083

# %% [markdown]
# We normalized all the variables.

# %%
DF_joined_cleaned_chosenDates_min=DF_joined_cleaned_chosenDates.min()
DF_joined_cleaned_chosenDates_max=DF_joined_cleaned_chosenDates.max()
DF_joined_cleaned_chosenDates_normalized= (DF_joined_cleaned_chosenDates-DF_joined_cleaned_chosenDates_min)/(DF_joined_cleaned_chosenDates_max-DF_joined_cleaned_chosenDates_min)
plt.figure()
DF_joined_cleaned_chosenDates_normalized.plot()

# %% [markdown]
# Creating lagged features
# First, reconstruct the dataframe by applying time-zone to the whole dataset.

# %%
DF_joined = DF_consumption.join([DF_Temperature,DF_irradiance])
DF_mod = DF_joined.copy()
DF_mod["temperature"]=DF_mod["temperature"].shift(-5)
DF_mod.dropna(inplace=True)

# %%
DF_mod.head()
DF_mod.describe()
# Out:
#        air conditioner_5545  temperature          gen
# count           8670.000000  8670.000000  8670.000000
# mean             345.707233    67.717625     0.975530
# std              655.969001    16.256376     1.421250
# min                0.000000    20.730000     0.000000
# 25%                0.000000    56.630000     0.000000
# 50%                0.000000    70.250000     0.012317
# 75%              411.575000    79.480000     1.669108
# max             2841.000000   101.050000     5.099667

# %% [markdown]
# We are going to shift our variable.

# %%
DF_mod["Temperature -1h"]= DF_mod["temperature"].shift(1)
DF_mod["Temperature -2h"]= DF_mod["temperature"].shift(2)
DF_mod["Temperature -3h"]= DF_mod["temperature"].shift(2)
DF_mod["Temperature -4h"]= DF_mod["temperature"].shift(2)
DF_mod["Temperature -5h"]= DF_mod["temperature"].shift(2)
DF_mod["Temperature -6h"]= DF_mod["temperature"].shift(2)
DF_mod.head()
# Out:
#                      air conditioner_5545  temperature       gen  \
# 2014-01-01 06:00:00                   0.0        38.85  0.000000
# 2014-01-01 07:00:00                   0.0        39.36  0.052800
# 2014-01-01 08:00:00                   0.0        37.86  0.773583
# 2014-01-01 09:00:00                   0.0        38.97  2.097700
# 2014-01-01 10:00:00                   0.0        45.85  3.036750
#
#                      Temperature -1h  Temperature -2h  Temperature -3h  \
# 2014-01-01 06:00:00              NaN              NaN              NaN
# 2014-01-01 07:00:00            38.85              NaN              NaN
# 2014-01-01 08:00:00            39.36            38.85            38.85
# 2014-01-01 09:00:00            37.86            39.36            39.36
# 2014-01-01 10:00:00            38.97            37.86            37.86
#
#                      Temperature -4h  Temperature -5h  Temperature -6h
# 2014-01-01 06:00:00              NaN              NaN              NaN
# 2014-01-01 07:00:00              NaN              NaN              NaN
# 2014-01-01 08:00:00            38.85            38.85            38.85
# 2014-01-01 09:00:00            39.36            39.36            39.36
# 2014-01-01 10:00:00            37.86            37.86            37.86

# %% [markdown]
# We can use functions in order to reduce the time of writing to much shifting for the variables.

# %%
lag_start=1
lag_end = 6
lag_interval=1

# %%
column_name="temperature"
df=DF_mod
for i in range(lag_start,lag_end+1,lag_interval):
    new_column_name = column_name+" -"+str(i)+"hr"
    print new_column_name
    df[new_column_name]=df[column_name].shift(i)   
    df.dropna(inplace=True) #this removes all the row with a Nan

def lag_feature(df,column_name,lag_start,lag_end,lag_interval):
    for i in range(lag_start,lag_end+1,lag_interval):
        new_column_name = column_name+" -"+str(i)+"hr"
        print new_column_name
        df[new_column_name]=df[column_name].shift(i)   
        df.dropna(inplace=True) #this removes all the row with a Nan
    return df
# Out:
# temperature -1hr
# temperature -2hr
# temperature -3hr
# temperature -4hr
# temperature -5hr
# temperature -6hr

# %% [markdown]
# Now we do the same for the irradiance and consumption but first we change the names of irradiance and consumption columns.

# %%
DF_mod=DF_mod.rename(columns={"air conditioner_5545":"AC_consumption","gen":"irradiance"})

# %%
DF_mod=  lag_feature(DF_mod,"temperature",1,6,1)
DF_mod.head()
# Out:
# temperature -1hr
# temperature -2hr
# temperature -3hr
# temperature -4hr
# temperature -5hr
# temperature -6hr
#                      AC_consumption  temperature  irradiance  Temperature -1h  \
# 2014-01-03 01:00:00             0.0        33.09         0.0            34.69
# 2014-01-03 02:00:00             0.0        30.79         0.0            33.09
# 2014-01-03 03:00:00             0.0        29.50         0.0            30.79
# 2014-01-03 04:00:00             0.0        30.37         0.0            29.50
# 2014-01-03 05:00:00             0.0        29.60         0.0            30.37
#
#                      Temperature -2h  Temperature -3h  Temperature -4h  \
# 2014-01-03 01:00:00            35.85            35.85            35.85
# 2014-01-03 02:00:00            34.69            34.69            34.69
# 2014-01-03 03:00:00            33.09            33.09            33.09
# 2014-01-03 04:00:00            30.79            30.79            30.79
# 2014-01-03 05:00:00            29.50            29.50            29.50
#
#                      Temperature -5h  Temperature -6h  temperature -1hr  \
# 2014-01-03 01:00:00            35.85            35.85             34.69
# 2014-01-03 02:00:00            34.69            34.69             33.09
# 2014-01-03 03:00:00            33.09            33.09             30.79
# 2014-01-03 04:00:00            30.79            30.79             29.50
# 2014-01-03 05:00:00            29.50            29.50             30.37
#
#                      temperature -2hr  temperature -3hr  temperature -4hr  \
# 2014-01-03 01:00:00             35.85             36.29             38.60
# 2014-01-03 02:00:00             34.69             35.85             36.29
# 2014-01-03 03:00:00             33.09             34.69             35.85
# 2014-01-03 04:00:00             30.79             33.09             34.69
# 2014-01-03 05:00:00             29.50             30.79             33.09
#
#                      temperature -5hr  temperature -6hr
# 2014-01-03 01:00:00             40.43             45.96
# 2014-01-03 02:00:00             38.60             40.43
# 2014-01-03 03:00:00             36.29             38.60
# 2014-01-03 04:00:00             35.85             36.29
# 2014-01-03 05:00:00             34.69             35.85

# %%
DF_mod=  lag_feature(DF_mod,"irradiance",3,6,1)
# Out:
# irradiance -3hr
# irradiance -4hr
# irradiance -5hr
# irradiance -6hr

# %% [markdown]
# We add the previous consumptions in the last 24 hours!

# %%
DF_mod=  lag_feature(DF_mod,"AC_consumption",1,24,1)
DF_mod.head()
DF_mod.describe()
# Out:
# AC_consumption -1hr
# AC_consumption -2hr
# AC_consumption -3hr
# AC_consumption -4hr
# AC_consumption -5hr
# AC_consumption -6hr
# AC_consumption -7hr
# AC_consumption -8hr
# AC_consumption -9hr
# AC_consumption -10hr
# AC_consumption -11hr
# AC_consumption -12hr
# AC_consumption -13hr
# AC_consumption -14hr
# AC_consumption -15hr
# AC_consumption -16hr
# AC_consumption -17hr
# AC_consumption -18hr
# AC_consumption -19hr
# AC_consumption -20hr
# AC_consumption -21hr
# AC_consumption -22hr
# AC_consumption -23hr
# AC_consumption -24hr
#        AC_consumption  temperature   irradiance  Temperature -1h  \
# count     8309.000000  8309.000000  8309.000000      8309.000000
# mean       360.727128    68.496584     0.980597        68.497029
# std        666.013384    15.941926     1.422228        15.941184
# min          0.000000    22.920000     0.000000        22.920000
# 25%          0.000000    57.780000     0.000000        57.780000
# 50%          0.000000    71.440000     0.014800        71.440000
# 75%        461.116667    79.970000     1.677400        79.970000
# max       2841.000000   101.050000     5.099667       101.050000
#
#        Temperature -2h  Temperature -3h  Temperature -4h  Temperature -5h  \
# count      8309.000000      8309.000000      8309.000000      8309.000000
# mean         68.497355        68.497355        68.497355        68.497355
# std          15.940631        15.940631        15.940631        15.940631
# min          22.920000        22.920000        22.920000        22.920000
# 25%          57.780000        57.780000        57.780000        57.780000
# 50%          71.440000        71.440000        71.440000        71.440000
# 75%          79.970000        79.970000        79.970000        79.970000
# max         101.050000       101.050000       101.050000       101.050000
#
#        Temperature -6h  temperature -1hr          ...           \
# count      8309.000000       8309.000000          ...
# mean         68.497355         68.497029          ...
# std          15.940631         15.941184          ...
# min          22.920000         22.920000          ...
# 25%          57.780000         57.780000          ...
# 50%          71.440000         71.440000          ...
# 75%          79.970000         79.970000          ...
# max         101.050000        101.050000          ...
#
#        AC_consumption -15hr  AC_consumption -16hr  AC_consumption -17hr  \
# count           8309.000000           8309.000000           8309.000000
# mean             360.727128            360.727128            360.727128
# std              666.013384            666.013384            666.013384
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%              461.116667            461.116667            461.116667
# max             2841.000000           2841.000000           2841.000000
#
#        AC_consumption -18hr  AC_consumption -19hr  AC_consumption -20hr  \
# count           8309.000000           8309.000000           8309.000000
# mean             360.727128            360.727128            360.727128
# std              666.013384            666.013384            666.013384
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%              461.116667            461.116667            461.116667
# max             2841.000000           2841.000000           2841.000000
#
#        AC_consumption -21hr  AC_consumption -22hr  AC_consumption -23hr  \
# count           8309.000000           8309.000000           8309.000000
# mean             360.727128            360.727128            360.727128
# std              666.013384            666.013384            666.013384
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%              461.116667            461.116667            461.116667
# max             2841.000000           2841.000000           2841.000000
#
#        AC_consumption -24hr
# count           8309.000000
# mean             360.727128
# std              666.013384
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%              461.116667
# max             2841.000000
#
# [8 rows x 43 columns]

# %% [markdown]
# To make the time continuous we apply sine and cosine functions to the hours to avoid the restart of the time at the beginning of each day (from 23:00 to 00:00).

# %%
DF_mod["hour"]=DF_mod.index.hour
DF_mod["hour"].head()
DF_mod["sin_hour"]=np.sin(DF_mod.index.hour*2*np.pi/24)
DF_mod["cos_hour"]=np.cos(DF_mod.index.hour*2*np.pi/24)

# %%
DF_mod["day_of_week"]=DF_mod.index.dayofweek
DF_mod[["hour","sin_hour","cos_hour","day_of_week"]].head(24)
# Out:
#                      hour      sin_hour      cos_hour  day_of_week
# 2014-01-16 07:00:00     7  9.659258e-01 -2.588190e-01            3
# 2014-01-16 08:00:00     8  8.660254e-01 -5.000000e-01            3
# 2014-01-16 09:00:00     9  7.071068e-01 -7.071068e-01            3
# 2014-01-16 10:00:00    10  5.000000e-01 -8.660254e-01            3
# 2014-01-16 11:00:00    11  2.588190e-01 -9.659258e-01            3
# 2014-01-16 12:00:00    12  1.224647e-16 -1.000000e+00            3
# 2014-01-16 13:00:00    13 -2.588190e-01 -9.659258e-01            3
# 2014-01-16 14:00:00    14 -5.000000e-01 -8.660254e-01            3
# 2014-01-16 15:00:00    15 -7.071068e-01 -7.071068e-01            3
# 2014-01-16 16:00:00    16 -8.660254e-01 -5.000000e-01            3
# 2014-01-16 17:00:00    17 -9.659258e-01 -2.588190e-01            3
# 2014-01-16 18:00:00    18 -1.000000e+00 -1.836970e-16            3
# 2014-01-16 19:00:00    19 -9.659258e-01  2.588190e-01            3
# 2014-01-16 20:00:00    20 -8.660254e-01  5.000000e-01            3
# 2014-01-16 21:00:00    21 -7.071068e-01  7.071068e-01            3
# 2014-01-16 22:00:00    22 -5.000000e-01  8.660254e-01            3
# 2014-01-16 23:00:00    23 -2.588190e-01  9.659258e-01            3
# 2014-01-17 00:00:00     0  0.000000e+00  1.000000e+00            4
# 2014-01-17 01:00:00     1  2.588190e-01  9.659258e-01            4
# 2014-01-17 02:00:00     2  5.000000e-01  8.660254e-01            4
# 2014-01-17 03:00:00     3  7.071068e-01  7.071068e-01            4
# 2014-01-17 04:00:00     4  8.660254e-01  5.000000e-01            4
# 2014-01-17 05:00:00     5  9.659258e-01  2.588190e-01            4
# 2014-01-17 06:00:00     6  1.000000e+00  6.123234e-17            4

# %% [markdown]
# Using newly added indices, we use functions to determine which days are part of weekends and workdays. We're finally adding them to the data frame. In this way, we can associate data and consumption behavior with the days of the week.

# %%
DF_mod["month"]=DF_mod.index.month
DF_mod["week_of_year"]=DF_mod.index.week

# %%
def WeekendDetector(day):
    if (day==5 or day == 6):
        weekendLabel=1
    else:
        weekendLabel=0
    return weekendLabel

# %%
DF_mod["weekend"]= DF_mod["day_of_week"].apply(WeekendDetector)

# %%
def DayDetector(hour):
    if (hour< 19 and hour>=9):
        DayLabel=1
    else:
        DayLabel=0
    return DayLabel

# %%
DF_mod["workingTime"] = DF_mod["hour"].apply(DayDetector)
DF_mod[["workingTime","weekend"]].head(24)
# Out:
#                      workingTime  weekend
# 2014-01-16 07:00:00            0        0
# 2014-01-16 08:00:00            0        0
# 2014-01-16 09:00:00            1        0
# 2014-01-16 10:00:00            1        0
# 2014-01-16 11:00:00            1        0
# 2014-01-16 12:00:00            1        0
# 2014-01-16 13:00:00            1        0
# 2014-01-16 14:00:00            1        0
# 2014-01-16 15:00:00            1        0
# 2014-01-16 16:00:00            1        0
# 2014-01-16 17:00:00            1        0
# 2014-01-16 18:00:00            1        0
# 2014-01-16 19:00:00            0        0
# 2014-01-16 20:00:00            0        0
# 2014-01-16 21:00:00            0        0
# 2014-01-16 22:00:00            0        0
# 2014-01-16 23:00:00            0        0
# 2014-01-17 00:00:00            0        0
# 2014-01-17 01:00:00            0        0
# 2014-01-17 02:00:00            0        0
# 2014-01-17 03:00:00            0        0
# 2014-01-17 04:00:00            0        0
# 2014-01-17 05:00:00            0        0
# 2014-01-17 06:00:00            0        0

# %% [markdown]
# With the command corr we do correlation of the values.

# %%
DF_mod.head()
DF_mod.columns
DF_mod.corr()
# Out:
#                       AC_consumption  temperature  irradiance  \
# AC_consumption              1.000000     0.568748   -0.012450
# temperature                 0.568748     1.000000    0.329088
# irradiance                 -0.012450     0.329088    1.000000
# Temperature -1h             0.608674     0.990933    0.240042
# Temperature -2h             0.637016     0.968239    0.142477
# Temperature -3h             0.637016     0.968239    0.142477
# Temperature -4h             0.637016     0.968239    0.142477
# Temperature -5h             0.637016     0.968239    0.142477
# Temperature -6h             0.637016     0.968239    0.142477
# temperature -1hr            0.608674     0.990933    0.240042
# temperature -2hr            0.637016     0.968239    0.142477
# temperature -3hr            0.650296     0.935070    0.045301
# temperature -4hr            0.647980     0.894851   -0.043374
# temperature -5hr            0.630432     0.850819   -0.116967
# temperature -6hr            0.598799     0.805846   -0.171368
# irradiance -3hr             0.365692     0.451336    0.560952
# irradiance -4hr             0.468968     0.431787    0.329846
# irradiance -5hr             0.535431     0.387265    0.104363
# irradiance -6hr             0.557019     0.324390   -0.094358
# AC_consumption -1hr         0.907138     0.521472   -0.119465
# AC_consumption -2hr         0.810539     0.470698   -0.205225
# AC_consumption -3hr         0.694029     0.419448   -0.267809
# AC_consumption -4hr         0.567774     0.371297   -0.309128
# AC_consumption -5hr         0.435065     0.329220   -0.329174
# AC_consumption -6hr         0.304720     0.294455   -0.328695
# AC_consumption -7hr         0.183708     0.268621   -0.309446
# AC_consumption -8hr         0.079709     0.252819   -0.274710
# AC_consumption -9hr        -0.004698     0.246629   -0.224759
# AC_consumption -10hr       -0.068379     0.251472   -0.157693
# AC_consumption -11hr       -0.109483     0.268673   -0.072296
# AC_consumption -12hr       -0.125121     0.297806    0.030476
# AC_consumption -13hr       -0.109695     0.337265    0.146760
# AC_consumption -14hr       -0.069337     0.384280    0.261910
# AC_consumption -15hr       -0.005962     0.435425    0.368465
# AC_consumption -16hr        0.078708     0.487701    0.452913
# AC_consumption -17hr        0.180332     0.535368    0.511005
# AC_consumption -18hr        0.299260     0.574983    0.533047
# AC_consumption -19hr        0.423738     0.603970    0.511007
# AC_consumption -20hr        0.550335     0.619397    0.443847
# AC_consumption -21hr        0.667572     0.620466    0.344082
# AC_consumption -22hr        0.769560     0.606459    0.220494
# AC_consumption -23hr        0.849187     0.577951    0.092432
# AC_consumption -24hr        0.899772     0.538586   -0.025046
# hour                        0.361793     0.243421    0.167418
# sin_hour                   -0.439525    -0.333024   -0.237655
# cos_hour                    0.213034    -0.145965   -0.740419
# day_of_week                -0.015010     0.037875   -0.028703
# month                       0.126705     0.158280   -0.033787
# week_of_year                0.137911     0.188847   -0.026007
# weekend                    -0.006843     0.036042   -0.031010
# workingTime                -0.053210     0.247436    0.766268
#
#                       Temperature -1h  Temperature -2h  Temperature -3h  \
# AC_consumption               0.608674         0.637016         0.637016
# temperature                  0.990933         0.968239         0.968239
# irradiance                   0.240042         0.142477         0.142477
# Temperature -1h              1.000000         0.990932         0.990932
# Temperature -2h              0.990932         1.000000         1.000000
# Temperature -3h              0.990932         1.000000         1.000000
# Temperature -4h              0.990932         1.000000         1.000000
# Temperature -5h              0.990932         1.000000         1.000000
# Temperature -6h              0.990932         1.000000         1.000000
# temperature -1hr             1.000000         0.990932         0.990932
# temperature -2hr             0.990932         1.000000         1.000000
# temperature -3hr             0.968231         0.990926         0.990926
# temperature -4hr             0.935064         0.968226         0.968226
# temperature -5hr             0.894847         0.935062         0.935062
# temperature -6hr             0.850812         0.894843         0.894843
# irradiance -3hr              0.441279         0.399572         0.399572
# irradiance -4hr              0.451338         0.441280         0.441280
# irradiance -5hr              0.431788         0.451339         0.451339
# irradiance -6hr              0.387264         0.431789         0.431789
# AC_consumption -1hr          0.568759         0.608684         0.608684
# AC_consumption -2hr          0.521481         0.568768         0.568768
# AC_consumption -3hr          0.470705         0.521488         0.521488
# AC_consumption -4hr          0.419452         0.470710         0.470710
# AC_consumption -5hr          0.371299         0.419456         0.419456
# AC_consumption -6hr          0.329220         0.371301         0.371301
# AC_consumption -7hr          0.294454         0.329220         0.329220
# AC_consumption -8hr          0.268618         0.294453         0.294453
# AC_consumption -9hr          0.252816         0.268617         0.268617
# AC_consumption -10hr         0.246626         0.252813         0.252813
# AC_consumption -11hr         0.251469         0.246623         0.246623
# AC_consumption -12hr         0.268670         0.251467         0.251467
# AC_consumption -13hr         0.297804         0.268668         0.268668
# AC_consumption -14hr         0.337265         0.297804         0.297804
# AC_consumption -15hr         0.384283         0.337266         0.337266
# AC_consumption -16hr         0.435430         0.384285         0.384285
# AC_consumption -17hr         0.487709         0.435434         0.435434
# AC_consumption -18hr         0.535378         0.487714         0.487714
# AC_consumption -19hr         0.574995         0.535385         0.535385
# AC_consumption -20hr         0.603983         0.575004         0.575004
# AC_consumption -21hr         0.619410         0.603993         0.603993
# AC_consumption -22hr         0.620479         0.619421         0.619421
# AC_consumption -23hr         0.606472         0.620490         0.620490
# AC_consumption -24hr         0.577963         0.606482         0.606482
# hour                         0.262953         0.270015         0.270015
# sin_hour                    -0.359785        -0.361925        -0.361925
# cos_hour                    -0.054465         0.040871         0.040871
# day_of_week                  0.036768         0.035782         0.035782
# month                        0.159004         0.159775         0.159775
# week_of_year                 0.189651         0.190466         0.190466
# weekend                      0.036004         0.035884         0.035884
# workingTime                  0.167737         0.079414         0.079414
#
#                       Temperature -4h  Temperature -5h  Temperature -6h  \
# AC_consumption               0.637016         0.637016         0.637016
# temperature                  0.968239         0.968239         0.968239
# irradiance                   0.142477         0.142477         0.142477
# Temperature -1h              0.990932         0.990932         0.990932
# Temperature -2h              1.000000         1.000000         1.000000
# Temperature -3h              1.000000         1.000000         1.000000
# Temperature -4h              1.000000         1.000000         1.000000
# Temperature -5h              1.000000         1.000000         1.000000
# Temperature -6h              1.000000         1.000000         1.000000
# temperature -1hr             0.990932         0.990932         0.990932
# temperature -2hr             1.000000         1.000000         1.000000
# temperature -3hr             0.990926         0.990926         0.990926
# temperature -4hr             0.968226         0.968226         0.968226
# temperature -5hr             0.935062         0.935062         0.935062
# temperature -6hr             0.894843         0.894843         0.894843
# irradiance -3hr              0.399572         0.399572         0.399572
# irradiance -4hr              0.441280         0.441280         0.441280
# irradiance -5hr              0.451339         0.451339         0.451339
# irradiance -6hr              0.431789         0.431789         0.431789
# AC_consumption -1hr          0.608684         0.608684         0.608684
# AC_consumption -2hr          0.568768         0.568768         0.568768
# AC_consumption -3hr          0.521488         0.521488         0.521488
# AC_consumption -4hr          0.470710         0.470710         0.470710
# AC_consumption -5hr          0.419456         0.419456         0.419456
# AC_consumption -6hr          0.371301         0.371301         0.371301
# AC_consumption -7hr          0.329220         0.329220         0.329220
# AC_consumption -8hr          0.294453         0.294453         0.294453
# AC_consumption -9hr          0.268617         0.268617         0.268617
# AC_consumption -10hr         0.252813         0.252813         0.252813
# AC_consumption -11hr         0.246623         0.246623         0.246623
# AC_consumption -12hr         0.251467         0.251467         0.251467
# AC_consumption -13hr         0.268668         0.268668         0.268668
# AC_consumption -14hr         0.297804         0.297804         0.297804
# AC_consumption -15hr         0.337266         0.337266         0.337266
# AC_consumption -16hr         0.384285         0.384285         0.384285
# AC_consumption -17hr         0.435434         0.435434         0.435434
# AC_consumption -18hr         0.487714         0.487714         0.487714
# AC_consumption -19hr         0.535385         0.535385         0.535385
# AC_consumption -20hr         0.575004         0.575004         0.575004
# AC_consumption -21hr         0.603993         0.603993         0.603993
# AC_consumption -22hr         0.619421         0.619421         0.619421
# AC_consumption -23hr         0.620490         0.620490         0.620490
# AC_consumption -24hr         0.606482         0.606482         0.606482
# hour                         0.270015         0.270015         0.270015
# sin_hour                    -0.361925        -0.361925        -0.361925
# cos_hour                     0.040871         0.040871         0.040871
# day_of_week                  0.035782         0.035782         0.035782
# month                        0.159775         0.159775         0.159775
# week_of_year                 0.190466         0.190466         0.190466
# weekend                      0.035884         0.035884         0.035884
# workingTime                  0.079414         0.079414         0.079414
#
#                       temperature -1hr     ...       AC_consumption -23hr  \
# AC_consumption                0.608674     ...                   0.849187
# temperature                   0.990933     ...                   0.577951
# irradiance                    0.240042     ...                   0.092432
# Temperature -1h               1.000000     ...                   0.606472
# Temperature -2h               0.990932     ...                   0.620490
# Temperature -3h               0.990932     ...                   0.620490
# Temperature -4h               0.990932     ...                   0.620490
# Temperature -5h               0.990932     ...                   0.620490
# Temperature -6h               0.990932     ...                   0.620490
# temperature -1hr              1.000000     ...                   0.606472
# temperature -2hr              0.990932     ...                   0.620490
# temperature -3hr              0.968231     ...                   0.619409
# temperature -4hr              0.935064     ...                   0.603968
# temperature -5hr              0.894847     ...                   0.574978
# temperature -6hr              0.850812     ...                   0.535366
# irradiance -3hr               0.441279     ...                   0.443847
# irradiance -4hr               0.451338     ...                   0.511007
# irradiance -5hr               0.431788     ...                   0.533047
# irradiance -6hr               0.387264     ...                   0.511005
# AC_consumption -1hr           0.568759     ...                   0.769560
# AC_consumption -2hr           0.521481     ...                   0.667572
# AC_consumption -3hr           0.470705     ...                   0.550335
# AC_consumption -4hr           0.419452     ...                   0.423738
# AC_consumption -5hr           0.371299     ...                   0.299260
# AC_consumption -6hr           0.329220     ...                   0.180332
# AC_consumption -7hr           0.294454     ...                   0.078708
# AC_consumption -8hr           0.268618     ...                  -0.005962
# AC_consumption -9hr           0.252816     ...                  -0.069337
# AC_consumption -10hr          0.246626     ...                  -0.109695
# AC_consumption -11hr          0.251469     ...                  -0.125121
# AC_consumption -12hr          0.268670     ...                  -0.109483
# AC_consumption -13hr          0.297804     ...                  -0.068379
# AC_consumption -14hr          0.337265     ...                  -0.004698
# AC_consumption -15hr          0.384283     ...                   0.079709
# AC_consumption -16hr          0.435430     ...                   0.183708
# AC_consumption -17hr          0.487709     ...                   0.304720
# AC_consumption -18hr          0.535378     ...                   0.435065
# AC_consumption -19hr          0.574995     ...                   0.567774
# AC_consumption -20hr          0.603983     ...                   0.694029
# AC_consumption -21hr          0.619410     ...                   0.810539
# AC_consumption -22hr          0.620479     ...                   0.907138
# AC_consumption -23hr          0.606472     ...                   1.000000
# AC_consumption -24hr          0.577963     ...                   0.907138
# hour                          0.262953     ...                   0.369811
# sin_hour                     -0.359785     ...                  -0.479294
# cos_hour                     -0.054465     ...                   0.092060
# day_of_week                   0.036768     ...                  -0.018580
# month                         0.159004     ...                   0.131707
# week_of_year                  0.189651     ...                   0.143134
# weekend                       0.036004     ...                  -0.016923
# workingTime                   0.167737     ...                   0.048427
#
#                       AC_consumption -24hr      hour  sin_hour  cos_hour  \
# AC_consumption                    0.899772  0.361793 -0.439525  0.213034
# temperature                       0.538586  0.243421 -0.333024 -0.145965
# irradiance                       -0.025046  0.167418 -0.237655 -0.740419
# Temperature -1h                   0.577963  0.262953 -0.359785 -0.054465
# Temperature -2h                   0.606482  0.270015 -0.361925  0.040871
# Temperature -3h                   0.606482  0.270015 -0.361925  0.040871
# Temperature -4h                   0.606482  0.270015 -0.361925  0.040871
# Temperature -5h                   0.606482  0.270015 -0.361925  0.040871
# Temperature -6h                   0.606482  0.270015 -0.361925  0.040871
# temperature -1hr                  0.577963  0.262953 -0.359785 -0.054465
# temperature -2hr                  0.606482  0.270015 -0.361925  0.040871
# temperature -3hr                  0.620479  0.261246 -0.339354  0.133520
# temperature -4hr                  0.619395  0.231874 -0.293590  0.217137
# temperature -5hr                  0.603964  0.176945 -0.227763  0.286029
# temperature -6hr                  0.574982  0.102655 -0.146354  0.335491
# irradiance -3hr                   0.344082  0.465600 -0.691979 -0.354928
# irradiance -4hr                   0.443847  0.563885 -0.760067 -0.163381
# irradiance -5hr                   0.511007  0.643793 -0.776214  0.039308
# irradiance -6hr                   0.533047  0.670914 -0.739318  0.239307
# AC_consumption -1hr               0.849187  0.325536 -0.369823  0.319585
# AC_consumption -2hr               0.769560  0.237468 -0.274938  0.404453
# AC_consumption -3hr               0.667572  0.113848 -0.161337  0.461853
# AC_consumption -4hr               0.550335 -0.050280 -0.036762  0.487874
# AC_consumption -5hr               0.423738 -0.147139  0.090299  0.480743
# AC_consumption -6hr               0.299260 -0.248486  0.211186  0.440945
# AC_consumption -7hr               0.180332 -0.343284  0.317660  0.371193
# AC_consumption -8hr               0.078708 -0.380411  0.402467  0.276240
# AC_consumption -9hr              -0.005962 -0.392264  0.459826  0.162557
# AC_consumption -10hr             -0.069337 -0.376137  0.485828  0.037891
# AC_consumption -11hr             -0.109695 -0.337001  0.478702 -0.089261
# AC_consumption -12hr             -0.125121 -0.278698  0.438933 -0.210235
# AC_consumption -13hr             -0.109483 -0.209280  0.369231 -0.316786
# AC_consumption -14hr             -0.068379 -0.134978  0.274346 -0.401654
# AC_consumption -15hr             -0.004698 -0.057836  0.160745 -0.459054
# AC_consumption -16hr              0.079709  0.019609  0.036170 -0.485075
# AC_consumption -17hr              0.183708  0.097729 -0.090891 -0.477944
# AC_consumption -18hr              0.304720  0.175479 -0.211778 -0.438146
# AC_consumption -19hr              0.435065  0.252847 -0.318252 -0.368394
# AC_consumption -20hr              0.567774  0.303817 -0.403059 -0.273441
# AC_consumption -21hr              0.694029  0.339089 -0.460418 -0.159758
# AC_consumption -22hr              0.810539  0.360011 -0.486420 -0.035093
# AC_consumption -23hr              0.907138  0.369811 -0.479294  0.092060
# AC_consumption -24hr              1.000000  0.361793 -0.439525  0.213034
# hour                              0.361793  1.000000 -0.776223 -0.102273
# sin_hour                         -0.439525 -0.776223  1.000000  0.000346
# cos_hour                          0.213034 -0.102273  0.000346  1.000000
# day_of_week                      -0.018742  0.000404 -0.000469  0.000390
# month                             0.131975 -0.001849  0.001480  0.001131
# week_of_year                      0.143386 -0.001086  0.001387  0.000640
# weekend                          -0.017735 -0.000151 -0.000001  0.000957
# workingTime                      -0.053210  0.245049 -0.339488 -0.816882
#
#                       day_of_week     month  week_of_year   weekend  \
# AC_consumption          -0.015010  0.126705      0.137911 -0.006843
# temperature              0.037875  0.158280      0.188847  0.036042
# irradiance              -0.028703 -0.033787     -0.026007 -0.031010
# Temperature -1h          0.036768  0.159004      0.189651  0.036004
# Temperature -2h          0.035782  0.159775      0.190466  0.035884
# Temperature -3h          0.035782  0.159775      0.190466  0.035884
# Temperature -4h          0.035782  0.159775      0.190466  0.035884
# Temperature -5h          0.035782  0.159775      0.190466  0.035884
# Temperature -6h          0.035782  0.159775      0.190466  0.035884
# temperature -1hr         0.036768  0.159004      0.189651  0.036004
# temperature -2hr         0.035782  0.159775      0.190466  0.035884
# temperature -3hr         0.035123  0.160653      0.191343  0.036078
# temperature -4hr         0.034652  0.161577      0.192237  0.036548
# temperature -5hr         0.034293  0.162548      0.193084  0.036998
# temperature -6hr         0.033964  0.163524      0.193876  0.037326
# irradiance -3hr         -0.028518 -0.033787     -0.026007 -0.031010
# irradiance -4hr         -0.028336 -0.033786     -0.026005 -0.031019
# irradiance -5hr         -0.028196 -0.033721     -0.025950 -0.030932
# irradiance -6hr         -0.027717 -0.033487     -0.025750 -0.030950
# AC_consumption -1hr     -0.016661  0.127063      0.138273 -0.009761
# AC_consumption -2hr     -0.018055  0.127584      0.138779 -0.011843
# AC_consumption -3hr     -0.017728  0.128116      0.139352 -0.013067
# AC_consumption -4hr     -0.017842  0.128767      0.140051 -0.013864
# AC_consumption -5hr     -0.016615  0.129233      0.140530 -0.014994
# AC_consumption -6hr     -0.014438  0.129766      0.141002 -0.014586
# AC_consumption -7hr     -0.011234  0.130215      0.141436 -0.014318
# AC_consumption -8hr     -0.011904  0.130627      0.141781 -0.013700
# AC_consumption -9hr     -0.014850  0.130922      0.142099 -0.014910
# AC_consumption -10hr    -0.015755  0.131047      0.142295 -0.014549
# AC_consumption -11hr    -0.017246  0.131126      0.142438 -0.015173
# AC_consumption -12hr    -0.018713  0.131169      0.142525 -0.016427
# AC_consumption -13hr    -0.019753  0.131186      0.142571 -0.017276
# AC_consumption -14hr    -0.020224  0.131186      0.142592 -0.017549
# AC_consumption -15hr    -0.020127  0.131186      0.142593 -0.017384
# AC_consumption -16hr    -0.020664  0.131186      0.142607 -0.017688
# AC_consumption -17hr    -0.020632  0.131186      0.142607 -0.017688
# AC_consumption -18hr    -0.020666  0.131186      0.142609 -0.017764
# AC_consumption -19hr    -0.020774  0.131186      0.142614 -0.017853
# AC_consumption -20hr    -0.020874  0.131254      0.142695 -0.018250
# AC_consumption -21hr    -0.020628  0.131365      0.142814 -0.018368
# AC_consumption -22hr    -0.019408  0.131507      0.142954 -0.017192
# AC_consumption -23hr    -0.018580  0.131707      0.143134 -0.016923
# AC_consumption -24hr    -0.018742  0.131975      0.143386 -0.017735
# hour                     0.000404 -0.001849     -0.001086 -0.000151
# sin_hour                -0.000469  0.001480      0.001387 -0.000001
# cos_hour                 0.000390  0.001131      0.000640  0.000957
# day_of_week              1.000000 -0.012780     -0.005481  0.789076
# month                   -0.012780  1.000000      0.960790 -0.003799
# week_of_year            -0.005481  0.960790      1.000000 -0.006669
# weekend                  0.789076 -0.003799     -0.006669  1.000000
# workingTime             -0.000354 -0.001164     -0.000861 -0.000997
#
#                       workingTime
# AC_consumption          -0.053210
# temperature              0.247436
# irradiance               0.766268
# Temperature -1h          0.167737
# Temperature -2h          0.079414
# Temperature -3h          0.079414
# Temperature -4h          0.079414
# Temperature -5h          0.079414
# Temperature -6h          0.079414
# temperature -1hr         0.167737
# temperature -2hr         0.079414
# temperature -3hr        -0.010039
# temperature -4hr        -0.094352
# temperature -5hr        -0.169513
# temperature -6hr        -0.232324
# irradiance -3hr          0.536459
# irradiance -4hr          0.362714
# irradiance -5hr          0.173153
# irradiance -6hr         -0.018374
# AC_consumption -1hr     -0.157646
# AC_consumption -2hr     -0.258651
# AC_consumption -3hr     -0.325753
# AC_consumption -4hr     -0.377869
# AC_consumption -5hr     -0.398221
# AC_consumption -6hr     -0.395964
# AC_consumption -7hr     -0.374128
# AC_consumption -8hr     -0.339305
# AC_consumption -9hr     -0.291220
# AC_consumption -10hr    -0.224982
# AC_consumption -11hr    -0.128302
# AC_consumption -12hr    -0.010462
# AC_consumption -13hr     0.130824
# AC_consumption -14hr     0.232593
# AC_consumption -15hr     0.321565
# AC_consumption -16hr     0.397541
# AC_consumption -17hr     0.431448
# AC_consumption -18hr     0.444097
# AC_consumption -19hr     0.429993
# AC_consumption -20hr     0.385955
# AC_consumption -21hr     0.300456
# AC_consumption -22hr     0.187699
# AC_consumption -23hr     0.048427
# AC_consumption -24hr    -0.053210
# hour                     0.245049
# sin_hour                -0.339488
# cos_hour                -0.816882
# day_of_week             -0.000354
# month                   -0.001164
# week_of_year            -0.000861
# weekend                 -0.000997
# workingTime              1.000000
#
# [51 rows x 51 columns]
