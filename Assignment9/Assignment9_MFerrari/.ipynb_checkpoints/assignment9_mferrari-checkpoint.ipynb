# %% [markdown]
# # Assignment 9

# %% [markdown]
# In this assignment I will try to explain all of the steps we went through in the _data-driven consumption prediction project_, for a building in Austin.

# %% [markdown]
# First, I'm importing all the modules I'll use later.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# With the following command I avoid the *warning* caused by the attempt of changing the value of objects in data frames.

# %%
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# I'm now changing the directory to the one where all the files I need are.

# %%
ExternalFilesFolder =  r"C:\Users\Mirko\Desktop\Assignment9_MFerrari"
os.chdir(ExternalFilesFolder)

# %% [markdown]
# Now I'm going to name the files present in the folder.

# %%
ConsumptionFileName= "consumption_5545.csv"
TemperatureFileName= "Austin_weather_2014.csv"
IrradianceFileName= "irradiance_2014_gen.csv"

# %% [markdown]
# Is now easier to find the **paths** necessary to reach these files.

# %%
path_consumptionFile = os.path.join(ExternalFilesFolder,ConsumptionFileName)
path_TemperatureFile = os.path.join(ExternalFilesFolder,TemperatureFileName)
path_IrradianceFile = os.path.join(ExternalFilesFolder,IrradianceFileName)

# %% [markdown]
# I can now create a dataframe which will include the data related to the yearly AC consumption.

# %%
DF_consumption = pd.read_csv(path_consumptionFile, sep=",", index_col=0)

# %% [markdown]
# With the next commands, I'm changing the type of the indexes from "object" to "datatime", because I'm interested in a _data-driven model_ now.

# %%
PreviousIndex = DF_consumption.index
NewParsedIndex= pd.to_datetime(PreviousIndex)
DF_consumption.index =NewParsedIndex

# %% [markdown]
# I'm doing the same thing with the weather file.

# %%
DF_weather = pd.read_csv(path_TemperatureFile,sep=";",index_col=0)
previousIndex_weather=DF_weather.index
newIndex_weather=pd.to_datetime(previousIndex_weather)
DF_weather.index = newIndex_weather

# %% [markdown]
# This last dataframe includes a lot of informations about Austin weather during the year, but I'm mostly interested in temperatures, then I'm going to extract just them, creating a new dataframe.

# %%
DF_Temperature= DF_weather[["temperature"]]

# %% [markdown]
# I'm now creating a new dataframe which includes the irradiance data in Austin, collected from a building provided with PV panels.

# %%
DF_irradianceSource = pd.read_csv(path_IrradianceFile,sep=";",index_col=1)

# %% [markdown]
# As for the weather one, also this last dataframe includes a lot of informations, more than I need in this case. Since I'm now interested only in irradiance, I'm creating a new dataframe which contains only this information.

# %%
DF_irradiance = DF_irradianceSource[["gen"]]

# %% [markdown]
# Since some of these are **negative**, I'm setting them to zero.

# %%
DF_irradiance["gen"]<0
DF_irradiance[DF_irradiance["gen"]<0] = 0

# %% [markdown]
# With the next commmand, I create a _new dataframe including the last three I've just created_.

# %%
DF_joined = DF_consumption.join([DF_Temperature,DF_irradiance])

# %% [markdown]
# I create now a copy of this last dataframe, to not modify the original one.

# %%
DF_mod = DF_joined.copy()

# %% [markdown]
# With the next command I'm going to apply the **time-zone** to the temperatures, which are reported in the file in standard conditions.

# %%
DF_mod["temperature"] = DF_mod["temperature"].shift(-5)

# %% [markdown]
# Since this last command skips rows, NaN are created in the dataframe, then I need to remove them.

# %%
DF_mod.dropna(inplace = True)

# %% [markdown]
# I can now define a function which creates new columns of temperature "lagged" in time. This has to be done because the actual consumption depends also on the temperature in the previous hours.

# %%
def lag_feature(DF,column_name,lag_start,lag_end, lag_interval):
    for i in range(lag_start,lag_end +1, lag_interval):
        new_column_name = column_name + "-" + str(i) + "hr"
        DF[new_column_name] = (DF[column_name]).shift(i)
        DF.dropna(inplace = True)
    return DF

# %% [markdown]
# Let's first apply this function to the temperature's column.

# %%
DF_mod = lag_feature(DF_mod,"temperature",1,6,1)

# %% [markdown]
# Before doing the same thing to the other columns of *DF_mod*, I want to rename them.

# %%
DF_mod = DF_mod.rename(columns = {"air conditioner_5545":"AC_consumption","gen":"irradiance"})

# %% [markdown]
# I now apply the function to the irradiance column, between 3 to 6 hours.

# %%
DF_mod = lag_feature(DF_mod,"irradiance",3,6,1)

# %% [markdown]
# For the AC consumption, I apply the function for the previous 24 hours.

# %%
DF_mod = lag_feature(DF_mod,"AC_consumption",1,24,1)

# %% [markdown]
# I've now to add the seasonality parameters (hours, days of the week, weeks of the year, months). These parameters are important because the consumption depends on the presence of people in the building, which depends on the hour/day we're considering ( work hour, festivity, sundays, etc.).

# %%
DF_mod["hour"] = DF_mod.index.hour

# %%
DF_mod["day_of_week"] = DF_mod.index.dayofweek

# %%
DF_mod["week_of_year"] = DF_mod.index.week

# %%
DF_mod["month"] = DF_mod.index.month

# %% [markdown]
# For the hours we've the problem that they're describing a continous time interval, with discontinuous values ( it goes from 0 to 23, and then back to 0 ).
# To solve this problem we can introduce the functions sine or cosine, which are continuous in time.

# %%
DF_mod["sin_hour"] = np.sin(DF_mod.index.hour*2*np.pi/24)
DF_mod["cos_hour"] = np.cos(DF_mod.index.hour*2*np.pi/24)

# %% [markdown]
# I can now define a function which separates weekends from working day.

# %%
def WeekendDetector(day):
    if (day == 5 or day == 6):
        weekendLabel = 1
    else:
        weekendLabel = 0
    return weekendLabel

# %% [markdown]
# I now create a new column in the dataframe, called **weekend** which reports if the day considered is a working day (0) or not (1).

# %%
DF_mod["weekend"] = DF_mod["day_of_week"].apply(WeekendDetector)

# %% [markdown]
# I can now define a function wich separates working hours from free time.

# %%
def DayDetector(hour):
    if (hour < 19 and hour >= 9):
        DayLabel = 1
    else:
        DayLabel = 0
    return DayLabel

# %% [markdown]
# I now create a new column in the dataframe, called **workingTime** which states if the hour considered is a working hour (1) or not (0).

# %%
DF_mod["workingTime"] = DF_mod["hour"].apply(DayDetector)

# %% [markdown]
# I'll now show all the columns of my new dataframe, and all the _correlations_ between them.

# %%
DF_mod.columns
# Out:
# Index([u'AC_consumption', u'temperature', u'irradiance', u'temperature-1hr',
#        u'temperature-2hr', u'temperature-3hr', u'temperature-4hr',
#        u'temperature-5hr', u'temperature-6hr', u'irradiance-3hr',
#        u'irradiance-4hr', u'irradiance-5hr', u'irradiance-6hr',
#        u'AC_consumption-1hr', u'AC_consumption-2hr', u'AC_consumption-3hr',
#        u'AC_consumption-4hr', u'AC_consumption-5hr', u'AC_consumption-6hr',
#        u'AC_consumption-7hr', u'AC_consumption-8hr', u'AC_consumption-9hr',
#        u'AC_consumption-10hr', u'AC_consumption-11hr', u'AC_consumption-12hr',
#        u'AC_consumption-13hr', u'AC_consumption-14hr', u'AC_consumption-15hr',
#        u'AC_consumption-16hr', u'AC_consumption-17hr', u'AC_consumption-18hr',
#        u'AC_consumption-19hr', u'AC_consumption-20hr', u'AC_consumption-21hr',
#        u'AC_consumption-22hr', u'AC_consumption-23hr', u'AC_consumption-24hr',
#        u'hour', u'day_of_week', u'month', u'week_of_year', u'sin_hour',
#        u'cos_hour', u'weekend', u'workingTime'],
#       dtype='object')

# %%
DF_mod.corr()
# Out:
#                      AC_consumption  temperature  irradiance  temperature-1hr  \
# AC_consumption             1.000000     0.568967   -0.012695         0.608771
# temperature                0.568967     1.000000    0.327736         0.990924
# irradiance                -0.012695     0.327736    1.000000         0.238627
# temperature-1hr            0.608771     0.990924    0.238627         1.000000
# temperature-2hr            0.637029     0.968215    0.141066         0.990924
# temperature-3hr            0.650286     0.935052    0.043916         0.968215
# temperature-4hr            0.647997     0.894855   -0.044694         0.935050
# temperature-5hr            0.630508     0.850852   -0.118168         0.894848
# temperature-6hr            0.598963     0.805907   -0.172384         0.850835
# irradiance-3hr             0.364543     0.450232    0.560763         0.440053
# irradiance-4hr             0.467584     0.430749    0.329518         0.450231
# irradiance-5hr             0.533896     0.386245    0.103919         0.430748
# irradiance-6hr             0.555435     0.323353   -0.094865         0.386245
# AC_consumption-1hr         0.907210     0.521817   -0.119464         0.568965
# AC_consumption-2hr         0.810686     0.471177   -0.205026         0.521814
# AC_consumption-3hr         0.694266     0.420062   -0.267466         0.471175
# AC_consumption-4hr         0.568108     0.372039   -0.308689         0.420061
# AC_consumption-5hr         0.435503     0.330073   -0.328689         0.372038
# AC_consumption-6hr         0.305258     0.295400   -0.328211         0.330073
# AC_consumption-7hr         0.184340     0.269635   -0.309007         0.295400
# AC_consumption-8hr         0.080421     0.253874   -0.274351         0.269635
# AC_consumption-9hr        -0.003920     0.247701   -0.224515         0.253875
# AC_consumption-10hr       -0.067552     0.252531   -0.157604         0.247702
# AC_consumption-11hr       -0.108624     0.269686   -0.072404         0.252532
# AC_consumption-12hr       -0.124250     0.298742    0.030131         0.269687
# AC_consumption-13hr       -0.108836     0.338097    0.146147         0.298742
# AC_consumption-14hr       -0.068509     0.384987    0.261032         0.338096
# AC_consumption-15hr       -0.005183     0.435997    0.367341         0.384987
# AC_consumption-16hr        0.079421     0.488135    0.451594         0.435996
# AC_consumption-17hr        0.180967     0.535676    0.509552         0.488133
# AC_consumption-18hr        0.299802     0.575186    0.531543         0.535673
# AC_consumption-19hr        0.424185     0.604096    0.509554         0.575184
# AC_consumption-20hr        0.550683     0.619482    0.442549         0.604093
# AC_consumption-21hr        0.667829     0.620548    0.343013         0.619479
# AC_consumption-22hr        0.769738     0.606578    0.219711         0.620545
# AC_consumption-23hr        0.849304     0.578146    0.091944         0.606575
# AC_consumption-24hr        0.899850     0.538885   -0.025262         0.578143
# hour                       0.361070     0.243124    0.167131         0.262693
# day_of_week               -0.014515     0.038664   -0.029183         0.037578
# month                      0.128627     0.162804   -0.034465         0.163573
# week_of_year               0.139760     0.193112   -0.026719         0.193957
# sin_hour                  -0.438641    -0.332523   -0.237118        -0.359332
# cos_hour                   0.212579    -0.146285   -0.740835        -0.054764
# weekend                   -0.005932     0.037955   -0.031255         0.037937
# workingTime               -0.053224     0.247145    0.766372         0.167417
#
#                      temperature-2hr  temperature-3hr  temperature-4hr  \
# AC_consumption              0.637029         0.650286         0.647997
# temperature                 0.968215         0.935052         0.894855
# irradiance                  0.141066         0.043916        -0.044694
# temperature-1hr             0.990924         0.968215         0.935050
# temperature-2hr             1.000000         0.990923         0.968213
# temperature-3hr             0.990923         1.000000         0.990923
# temperature-4hr             0.968213         0.990923         1.000000
# temperature-5hr             0.935045         0.968210         0.990922
# temperature-6hr             0.894836         0.935035         0.968205
# irradiance-3hr              0.398205         0.327602         0.238492
# irradiance-4hr              0.440054         0.398205         0.327600
# irradiance-5hr              0.450231         0.440054         0.398205
# irradiance-6hr              0.430749         0.450232         0.440054
# AC_consumption-1hr          0.608774         0.637030         0.650291
# AC_consumption-2hr          0.568967         0.608775         0.637035
# AC_consumption-3hr          0.521816         0.568968         0.608780
# AC_consumption-4hr          0.471176         0.521817         0.568972
# AC_consumption-5hr          0.420062         0.471177         0.521820
# AC_consumption-6hr          0.372039         0.420062         0.471179
# AC_consumption-7hr          0.330073         0.372039         0.420064
# AC_consumption-8hr          0.295400         0.330073         0.372040
# AC_consumption-9hr          0.269635         0.295400         0.330073
# AC_consumption-10hr         0.253874         0.269634         0.295400
# AC_consumption-11hr         0.247701         0.253874         0.269633
# AC_consumption-12hr         0.252531         0.247701         0.253873
# AC_consumption-13hr         0.269686         0.252531         0.247700
# AC_consumption-14hr         0.298742         0.269686         0.252530
# AC_consumption-15hr         0.338096         0.298742         0.269685
# AC_consumption-16hr         0.384987         0.338097         0.298741
# AC_consumption-17hr         0.435997         0.384988         0.338097
# AC_consumption-18hr         0.488135         0.435997         0.384988
# AC_consumption-19hr         0.535675         0.488136         0.435999
# AC_consumption-20hr         0.575186         0.535676         0.488138
# AC_consumption-21hr         0.604096         0.575187         0.535680
# AC_consumption-22hr         0.619481         0.604097         0.575191
# AC_consumption-23hr         0.620548         0.619483         0.604101
# AC_consumption-24hr         0.606578         0.620549         0.619488
# hour                        0.269813         0.261097         0.231785
# day_of_week                 0.036610         0.035980         0.035539
# month                       0.164362         0.165203         0.166071
# week_of_year                0.194789         0.195631         0.196473
# sin_hour                   -0.361499        -0.338919        -0.293132
# cos_hour                    0.040584         0.133246         0.216867
# weekend                     0.037825         0.038007         0.038456
# workingTime                 0.079101        -0.010368        -0.094670
#
#                      temperature-5hr  temperature-6hr  irradiance-3hr  \
# AC_consumption              0.630508         0.598963        0.364543
# temperature                 0.850852         0.805907        0.450232
# irradiance                 -0.118168        -0.172384        0.560763
# temperature-1hr             0.894848         0.850835        0.440053
# temperature-2hr             0.935045         0.894836        0.398205
# temperature-3hr             0.968210         0.935035        0.327602
# temperature-4hr             0.990922         0.968205        0.238492
# temperature-5hr             1.000000         0.990920        0.140920
# temperature-6hr             0.990920         1.000000        0.043755
# irradiance-3hr              0.140920         0.043755        1.000000
# irradiance-4hr              0.238487         0.140905        0.925908
# irradiance-5hr              0.327597         0.238477        0.769298
# irradiance-6hr              0.398204         0.327591        0.560726
# AC_consumption-1hr          0.648005         0.630520        0.237882
# AC_consumption-2hr          0.650300         0.648018        0.107989
# AC_consumption-3hr          0.637043         0.650312       -0.012739
# AC_consumption-4hr          0.608787         0.637055       -0.119511
# AC_consumption-5hr          0.568978         0.608798       -0.205075
# AC_consumption-6hr          0.521825         0.568987       -0.267517
# AC_consumption-7hr          0.471183         0.521832       -0.308742
# AC_consumption-8hr          0.420066         0.471188       -0.328742
# AC_consumption-9hr          0.372041         0.420068       -0.328265
# AC_consumption-10hr         0.330073         0.372041       -0.309060
# AC_consumption-11hr         0.295398         0.330071       -0.274403
# AC_consumption-12hr         0.269632         0.295395       -0.224565
# AC_consumption-13hr         0.253871         0.269627       -0.157652
# AC_consumption-14hr         0.247697         0.253866       -0.072449
# AC_consumption-15hr         0.252528         0.247692        0.030089
# AC_consumption-16hr         0.269683         0.252523        0.146108
# AC_consumption-17hr         0.298740         0.269679        0.260997
# AC_consumption-18hr         0.338097         0.298737        0.367310
# AC_consumption-19hr         0.384990         0.338095        0.451565
# AC_consumption-20hr         0.436002         0.384990        0.509526
# AC_consumption-21hr         0.488142         0.436005        0.531517
# AC_consumption-22hr         0.535685         0.488147        0.509528
# AC_consumption-23hr         0.575197         0.535692        0.442520
# AC_consumption-24hr         0.604109         0.575207        0.342982
# hour                        0.176851         0.102506        0.465340
# day_of_week                 0.035229         0.034955       -0.029040
# month                       0.167000         0.167940       -0.034603
# week_of_year                0.197279         0.198039       -0.026854
# sin_hour                   -0.227286        -0.145865       -0.691844
# cos_hour                    0.285755         0.335197       -0.355625
# weekend                     0.038891         0.039206       -0.031306
# workingTime                -0.169806        -0.232576        0.536995
#
#                         ...       AC_consumption-23hr  AC_consumption-24hr  \
# AC_consumption          ...                  0.849304             0.899850
# temperature             ...                  0.578146             0.538885
# irradiance              ...                  0.091944            -0.025262
# temperature-1hr         ...                  0.606575             0.578143
# temperature-2hr         ...                  0.620548             0.606578
# temperature-3hr         ...                  0.619483             0.620549
# temperature-4hr         ...                  0.604101             0.619488
# temperature-5hr         ...                  0.575197             0.604109
# temperature-6hr         ...                  0.535692             0.575207
# irradiance-3hr          ...                  0.442520             0.342982
# irradiance-4hr          ...                  0.509528             0.442520
# irradiance-5hr          ...                  0.531517             0.509528
# irradiance-6hr          ...                  0.509526             0.531517
# AC_consumption-1hr      ...                  0.769738             0.849304
# AC_consumption-2hr      ...                  0.667829             0.769738
# AC_consumption-3hr      ...                  0.550683             0.667829
# AC_consumption-4hr      ...                  0.424185             0.550683
# AC_consumption-5hr      ...                  0.299802             0.424185
# AC_consumption-6hr      ...                  0.180967             0.299802
# AC_consumption-7hr      ...                  0.079421             0.180967
# AC_consumption-8hr      ...                 -0.005183             0.079421
# AC_consumption-9hr      ...                 -0.068509            -0.005183
# AC_consumption-10hr     ...                 -0.108836            -0.068509
# AC_consumption-11hr     ...                 -0.124250            -0.108836
# AC_consumption-12hr     ...                 -0.108624            -0.124250
# AC_consumption-13hr     ...                 -0.067552            -0.108624
# AC_consumption-14hr     ...                 -0.003920            -0.067552
# AC_consumption-15hr     ...                  0.080421            -0.003920
# AC_consumption-16hr     ...                  0.184340             0.080421
# AC_consumption-17hr     ...                  0.305258             0.184340
# AC_consumption-18hr     ...                  0.435503             0.305258
# AC_consumption-19hr     ...                  0.568108             0.435503
# AC_consumption-20hr     ...                  0.694266             0.568108
# AC_consumption-21hr     ...                  0.810686             0.694266
# AC_consumption-22hr     ...                  0.907210             0.810686
# AC_consumption-23hr     ...                  1.000000             0.907210
# AC_consumption-24hr     ...                  0.907210             1.000000
# hour                    ...                  0.369074             0.361070
# day_of_week             ...                 -0.018084            -0.018245
# month                   ...                  0.133607             0.133874
# week_of_year            ...                  0.144962             0.145212
# sin_hour                ...                 -0.478346            -0.438641
# cos_hour                ...                  0.091821             0.212579
# weekend                 ...                 -0.016004            -0.016815
# workingTime             ...                  0.048236            -0.053224
#
#                          hour  day_of_week     month  week_of_year  sin_hour  \
# AC_consumption       0.361070    -0.014515  0.128627      0.139760 -0.438641
# temperature          0.243124     0.038664  0.162804      0.193112 -0.332523
# irradiance           0.167131    -0.029183 -0.034465     -0.026719 -0.237118
# temperature-1hr      0.262693     0.037578  0.163573      0.193957 -0.359332
# temperature-2hr      0.269813     0.036610  0.164362      0.194789 -0.361499
# temperature-3hr      0.261097     0.035980  0.165203      0.195631 -0.338919
# temperature-4hr      0.231785     0.035539  0.166071      0.196473 -0.293132
# temperature-5hr      0.176851     0.035229  0.167000      0.197279 -0.227286
# temperature-6hr      0.102506     0.034955  0.167940      0.198039 -0.145865
# irradiance-3hr       0.465340    -0.029040 -0.034603     -0.026854 -0.691844
# irradiance-4hr       0.563651    -0.028858 -0.034602     -0.026853 -0.760103
# irradiance-5hr       0.643644    -0.028718 -0.034538     -0.026798 -0.776404
# irradiance-6hr       0.671023    -0.028240 -0.034305     -0.026599 -0.739635
# AC_consumption-1hr   0.324878    -0.016165  0.128984      0.140121 -0.369053
# AC_consumption-2hr   0.236967    -0.017559  0.129502      0.140625 -0.274323
# AC_consumption-3hr   0.113568    -0.017232  0.130032      0.141196 -0.160906
# AC_consumption-4hr  -0.050265    -0.017346  0.130680      0.141891 -0.036533
# AC_consumption-5hr  -0.146951    -0.016119  0.131145      0.142368  0.090321
# AC_consumption-6hr  -0.248116    -0.013944  0.131675      0.142839  0.211011
# AC_consumption-7hr  -0.342744    -0.010742  0.132122      0.143270  0.317313
# AC_consumption-8hr  -0.379805    -0.011412  0.132532      0.143614  0.401982
# AC_consumption-9hr  -0.391637    -0.014356  0.132826      0.143930  0.459247
# AC_consumption-10hr -0.375539    -0.015260  0.132951      0.144126  0.485207
# AC_consumption-11hr -0.336473    -0.016750  0.133029      0.144268  0.478093
# AC_consumption-12hr -0.278274    -0.018216  0.133072      0.144355  0.438388
# AC_consumption-13hr -0.208981    -0.019255  0.133089      0.144401  0.368800
# AC_consumption-14hr -0.134811    -0.019726  0.133089      0.144422  0.274069
# AC_consumption-15hr -0.057808    -0.019629  0.133089      0.144423  0.160653
# AC_consumption-16hr  0.019499    -0.020166  0.133089      0.144436  0.036280
# AC_consumption-17hr  0.097479    -0.020134  0.133089      0.144436 -0.090574
# AC_consumption-18hr  0.175089    -0.020168  0.133089      0.144439 -0.211265
# AC_consumption-19hr  0.252319    -0.020276  0.133089      0.144444 -0.317566
# AC_consumption-20hr  0.303198    -0.020376  0.133157      0.144524 -0.402235
# AC_consumption-21hr  0.338406    -0.020130  0.133267      0.144642 -0.459501
# AC_consumption-22hr  0.359291    -0.018911  0.133408      0.144782 -0.485461
# AC_consumption-23hr  0.369074    -0.018084  0.133607      0.144962 -0.478346
# AC_consumption-24hr  0.361070    -0.018245  0.133874      0.145212 -0.438641
# hour                 1.000000    -0.000182 -0.002079     -0.001317 -0.776230
# day_of_week         -0.000182     1.000000 -0.011176     -0.003936  0.000052
# month               -0.002079    -0.011176  1.000000      0.961093  0.002012
# week_of_year        -0.001317    -0.003936  0.961093      1.000000  0.001910
# sin_hour            -0.776230     0.000052  0.002012      0.001910  1.000000
# cos_hour            -0.102352     0.000688  0.000891      0.000406  0.000509
# weekend             -0.000239     0.789050 -0.000895     -0.003803  0.000196
# workingTime          0.244960    -0.000807 -0.001499     -0.001192 -0.339320
#
#                      cos_hour   weekend  workingTime
# AC_consumption       0.212579 -0.005932    -0.053224
# temperature         -0.146285  0.037955     0.247145
# irradiance          -0.740835 -0.031255     0.766372
# temperature-1hr     -0.054764  0.037937     0.167417
# temperature-2hr      0.040584  0.037825     0.079101
# temperature-3hr      0.133246  0.038007    -0.010368
# temperature-4hr      0.216867  0.038456    -0.094670
# temperature-5hr      0.285755  0.038891    -0.169806
# temperature-6hr      0.335197  0.039206    -0.232576
# irradiance-3hr      -0.355625 -0.031306     0.536995
# irradiance-4hr      -0.164067 -0.031314     0.363244
# irradiance-5hr       0.038673 -0.031228     0.173616
# irradiance-6hr       0.238762 -0.031246    -0.018028
# AC_consumption-1hr   0.318939 -0.008848    -0.157479
# AC_consumption-2hr   0.403655 -0.010929    -0.258307
# AC_consumption-3hr   0.460952 -0.012151    -0.325293
# AC_consumption-4hr   0.486927 -0.012947    -0.377318
# AC_consumption-5hr   0.479808 -0.014076    -0.397635
# AC_consumption-6hr   0.440082 -0.013669    -0.395381
# AC_consumption-7hr   0.370455 -0.013401    -0.373584
# AC_consumption-8hr   0.275672 -0.012783    -0.338821
# AC_consumption-9hr   0.162192 -0.013992    -0.290820
# AC_consumption-10hr  0.037750 -0.013632    -0.224697
# AC_consumption-11hr -0.089174 -0.014255    -0.128185
# AC_consumption-12hr -0.209932 -0.015508    -0.010550
# AC_consumption-13hr -0.316292 -0.016356     0.130489
# AC_consumption-14hr -0.401008 -0.016629     0.232082
# AC_consumption-15hr -0.458305 -0.016464     0.320898
# AC_consumption-16hr -0.484280 -0.016768     0.396742
# AC_consumption-17hr -0.477161 -0.016768     0.430590
# AC_consumption-18hr -0.437435 -0.016844     0.443217
# AC_consumption-19hr -0.367807 -0.016932     0.429138
# AC_consumption-20hr -0.273025 -0.017329     0.385176
# AC_consumption-21hr -0.159545 -0.017447     0.299826
# AC_consumption-22hr -0.035103 -0.016273     0.187265
# AC_consumption-23hr  0.091821 -0.016004     0.048236
# AC_consumption-24hr  0.212579 -0.016815    -0.053224
# hour                -0.102352 -0.000239     0.244960
# day_of_week          0.000688  0.789050    -0.000807
# month                0.000891 -0.000895    -0.001499
# week_of_year         0.000406 -0.003803    -0.001192
# sin_hour             0.000509  0.000196    -0.339320
# cos_hour             1.000000  0.000869    -0.817092
# weekend              0.000869  1.000000    -0.001120
# workingTime         -0.817092 -0.001120     1.000000
#
# [45 rows x 45 columns]

# %% [markdown]
# From this last table we can notice that the actual AC consumption is correlated mainly ( >0.8 ) to the AC consumption in the very previous two hours and to the one of the previous day in the same hour. We can also see that the AC consumption depends more on the prevoius hour temperatures than on the actual one. Same for irradiance ( this is due to the reason that irradiance process takes time to occur ).
